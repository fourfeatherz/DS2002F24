# %% [markdown]
# <a href="https://colab.research.google.com/github/fourfeatherz/DS2002F24/blob/main/Labs%20/Vizdata/Visualization_Libraries_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Visualization Libraries Demo
# This notebook demonstrates the usage of various Python visualization libraries:
#
# - Matplotlib
# - Seaborn
# - Plotly
# - Bokeh
# - Altair
# - Dash
# - Pygal
# - NetworkX
# - Geopandas + Folium
# - Mayavi
# - Holoviews
#
# Each library will be demonstrated with simple examples using publicly available datasets.

# %% [markdown]
# ## 1. Matplotlib
# Matplotlib is a versatile library for creating static, animated, and interactive plots.

# %%
# Import Matplotlib
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create a basic line plot
plt.figure(figsize=(8, 5))
plt.plot(x, y, label='Sine Wave')
plt.title('Matplotlib Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. Seaborn
# Seaborn builds on Matplotlib to provide beautiful statistical plots.

# %%
# Import Seaborn
# Import Seaborn and Matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Tips dataset
tips = sns.load_dataset('tips')

# Compute the correlation matrix using only numeric columns
numeric_tips = tips.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numeric_tips.corr()

# Create a heatmap
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Seaborn Heatmap of Numeric Features in Tips Dataset')
plt.show()

# %% [markdown]
# ## 3. Iris Dataset Visualization with Seaborn
# Using the Iris dataset, we demonstrate how to create pair plots and scatter plots.

# %%
# Load the Iris dataset
iris = pd.read_csv('iris_dataset.csv')

# Create a pairplot with Seaborn
sns.pairplot(iris, hue='target')
plt.title('Seaborn Pairplot of Iris Dataset')
plt.show()

# %% [markdown]
# ## 4. Gapminder Dataset Visualization with Plotly
# Using the Gapminder dataset, we create interactive scatter plots.

# %%
import plotly.express as px
import pandas as pd

# Load the Gapminder-like dataset
gapminder = pd.read_csv('gapminder_dataset.csv')

# Create an interactive scatter plot
fig = px.scatter(
    gapminder,
    x='GDP per Capita',
    y='Life Expectancy',
    size='Population',  # Bubble size represents population
    color='Country',
    animation_frame='Year',  # Animate over years
    title='Interactive Gapminder-like Scatter Plot'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 6. Airbnb Dataset Mapping with Folium
# Using the Airbnb dataset, we map locations and prices.

# %%
# Load the Airbnb dataset
airbnb = pd.read_csv('airbnb_dataset.csv')

# Create a Folium map
import folium
map_airbnb = folium.Map(location=[40.7, -73.85], zoom_start=12)

# Add markers for each Airbnb listing
for _, row in airbnb.iterrows():
    folium.Marker(
        location=[row['Latitude'], row['Longitude']],
        popup=f"Price: ${row['Price']} | Rating: {row['Rating']:.1f}"
    ).add_to(map_airbnb)

# Display the map
map_airbnb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## 7. Social Network Visualization with NetworkX
# Using a sample social network dataset, we visualize connections.

# %%
# Load the social network edges
social_edges = pd.read_csv('social_network_edges.csv')

# Create a graph with NetworkX
import networkx as nx
G = nx.from_pandas_edgelist(social_edges, source='source', target='target')

# Draw the graph
plt.figure(figsize=(8, 8))
nx.draw(G, with_labels=True, node_color='lightblue', edge_color='gray', node_size=500)
plt.title('Social Network Graph')
plt.show()
